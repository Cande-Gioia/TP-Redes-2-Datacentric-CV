# %% [markdown]
# ## Inicialización: dataset + dependencias

# %%
# !pip install mlflow -q
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 24.8.3 requires cubinlinker, which is not installed.
# cudf 24.8.3 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 24.8.3 requires ptxcompiler, which is not installed.
# cuml 24.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 24.8.3 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 24.8.3 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.6.0 which is incompatible.
# dataproc-jupyter-plugin 0.1.79 requires pydantic~=1.10.0, but you have pydantic 2.9.2 which is incompatible.
# kfp 2.5.0 requires google-cloud-storage<3,>=2.2.1, but you have google-cloud-storage 1.44.0 which is incompatible.

# %%
# !pip install gdown
# Out:
# Collecting gdown
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from gdown) (3.15.1)
# Requirement already satisfied: requests[socks] in /opt/conda/lib/python3.10/site-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from gdown) (4.66.4)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.7.1)
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Installing collected packages: gdown
# Successfully installed gdown-5.2.0

# %%
import tensorflow as tf

from tensorflow.keras.callbacks import TensorBoard

from tensorboard.plugins.hparams import api as hp

import mlflow

from tensorflow.keras.applications import ResNet50

from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout

from tensorflow.keras import Sequential

from tensorflow.keras.models import Model

from tensorflow.keras.optimizers import Adam

from functools import partial

import matplotlib.pyplot as plt

import albumentations as A

import numpy as np
# Out:
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.21 (you have 1.4.17). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
# !gdown --id 1--m8IGrdaNgf1ocUXBqJjnHBo3ZaxN0E
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# /opt/conda/lib/python3.10/site-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1--m8IGrdaNgf1ocUXBqJjnHBo3ZaxN0E
# From (redirected): https://drive.google.com/uc?id=1--m8IGrdaNgf1ocUXBqJjnHBo3ZaxN0E&confirm=t&uuid=cbea2d69-21af-4a7c-b356-5adc9d266b31
# To: /kaggle/working/dataset.zip
# 100%|█████████████████████████████████████████| 240M/240M [00:01<00:00, 212MB/s]

# %%
#Unzip quietly
# !unzip /kaggle/working/dataset.zip -d /kaggle/working/dataset && rm /kaggle/working/dataset.zip
# Out:
# Archive:  /kaggle/working/dataset.zip
#    creating: /kaggle/working/dataset/American coot/
#    creating: /kaggle/working/dataset/Cheops/
#    creating: /kaggle/working/dataset/Moorish arch/
#    creating: /kaggle/working/dataset/Pharaoh/
#    creating: /kaggle/working/dataset/alcoholic/
#    creating: /kaggle/working/dataset/book bag/
#    creating: /kaggle/working/dataset/chime/
#    creating: /kaggle/working/dataset/cirque/
#    creating: /kaggle/working/dataset/great grandparent/
#    creating: /kaggle/working/dataset/hill myna/
#    creating: /kaggle/working/dataset/kitchenware/
#    creating: /kaggle/working/dataset/larva/
#    creating: /kaggle/working/dataset/masterpiece/
#    creating: /kaggle/working/dataset/mousse/
#    creating: /kaggle/working/dataset/plastic wrap/
#    creating: /kaggle/working/dataset/shield/
#    creating: /kaggle/working/dataset/stately home/
#    creating: /kaggle/working/dataset/sweet William/
#    creating: /kaggle/working/dataset/toy box/
#    creating: /kaggle/working/dataset/yellowfin/
#   inflating: /kaggle/working/dataset/mousse/3821147919_fee8b62c1c.jpg
#   inflating: /kaggle/working/dataset/mousse/315086095_62ab7de49e.jpg
#   inflating: /kaggle/working/dataset/mousse/3167525796_7d3fe288f0.jpg
#   inflating: /kaggle/working/dataset/mousse/3518137891_a4ed092947.jpg
#   inflating: /kaggle/working/dataset/mousse/90901919_9771a99d79.jpg
#   inflating: /kaggle/working/dataset/mousse/864845220_7cb189f941.jpg
#   inflating: /kaggle/working/dataset/mousse/2743062578_a4d4a84edb.jpg
#   inflating: /kaggle/working/dataset/mousse/451102440_8f0f282bab.jpg
#   inflating: /kaggle/working/dataset/mousse/3263701391_a6fb3c14f0.jpg
#   inflating: /kaggle/working/dataset/mousse/3975703208_4e9db690cf.jpg
#   inflating: /kaggle/working/dataset/mousse/3612850787_b9f51a74b4.jpg
#   inflating: /kaggle/working/dataset/mousse/2921102466_f747e29087.jpg
#   inflating: /kaggle/working/dataset/mousse/227193273_721316489f.jpg
#   inflating: /kaggle/working/dataset/mousse/101507774_125c94f675.jpg
#   inflating: /kaggle/working/dataset/mousse/2998334436_062e5da2f1.jpg
#   inflating: /kaggle/working/dataset/mousse/3713878345_203843c2b1.jpg
#   inflating: /kaggle/working/dataset/mousse/2265931043_39bcabf20e.jpg
#   inflating: /kaggle/working/dataset/mousse/3886842442_15f723bf2b.jpg
#   inflating: /kaggle/working/dataset/mousse/3692644697_1686226a7b.jpg
#   inflating: /kaggle/working/dataset/mousse/3117978018_aa53cb8260.jpg
#   inflating: /kaggle/working/dataset/mousse/400258602_89bd1e3bb7.jpg
#   inflating: /kaggle/working/dataset/mousse/3437017743_dcba2c670f.jpg
#   inflating: /kaggle/working/dataset/mousse/220688147_57ae6e2a04.jpg
#   inflating: /kaggle/working/dataset/mousse/3205090148_e601e023c9.jpg
#   inflating: /kaggle/working/dataset/mousse/3111964819_0251342aa2.jpg
#   inflating: /kaggle/working/dataset/mousse/2705266507_acf2d443f5.jpg
#   inflating: /kaggle/working/dataset/mousse/2242151882_371602f9f7_o.jpg
#   inflating: /kaggle/working/dataset/mousse/3461396051_de01642dd0.jpg
#   inflating: /kaggle/working/dataset/mousse/4252722303_b98fdfd92c.jpg
#   inflating: /kaggle/working/dataset/mousse/4212454115_de08862b9e.jpg
#   inflating: /kaggle/working/dataset/mousse/4182067560_1a62c3b603.jpg
#   inflating: /kaggle/working/dataset/mousse/3886854774_20ca863216.jpg
#   inflating: /kaggle/working/dataset/mousse/3444354713_35848d080a.jpg
#   inflating: /kaggle/working/dataset/mousse/2080093141_eabc9753b3.jpg
#   inflating: /kaggle/working/dataset/mousse/370516197_8e7728e51c.jpg
#   inflating: /kaggle/working/dataset/mousse/4223577191_d271fcfec9.jpg
#   inflating: /kaggle/working/dataset/mousse/2266702516_26ca914b14.jpg
#   inflating: /kaggle/working/dataset/mousse/1309156573_57869df5b6.jpg
#   inflating: /kaggle/working/dataset/mousse/2607065356_c279d166f5.jpg
#   inflating: /kaggle/working/dataset/mousse/3252718144_37af3c7f5a.jpg
#   inflating: /kaggle/working/dataset/mousse/911153892_dd500a8587.jpg
#   inflating: /kaggle/working/dataset/mousse/3242778904_459c9df840.jpg
#   inflating: /kaggle/working/dataset/mousse/112013865_d63f4a6e09.jpg
#   inflating: /kaggle/working/dataset/mousse/3275807682_a15457234a.jpg
#   inflating: /kaggle/working/dataset/mousse/2549150767_d95df015d1.jpg
#   inflating: /kaggle/working/dataset/mousse/492715050_e9cf6de200.jpg
#   inflating: /kaggle/working/dataset/mousse/2254440283_df9e781b33.jpg
#   inflating: /kaggle/working/dataset/mousse/348655591_f28711c730.jpg
#   inflating: /kaggle/working/dataset/mousse/2296286787_50a593f991.jpg
#   inflating: /kaggle/working/dataset/mousse/3280235683_0421303de5.jpg
#   inflating: /kaggle/working/dataset/mousse/1095784098_d2f46947a6.jpg
#   inflating: /kaggle/working/dataset/mousse/3996580941_590dcb2e94.jpg
#   inflating: /kaggle/working/dataset/mousse/9445105_0f34f109ce.jpg
#   inflating: /kaggle/working/dataset/mousse/2931905322_26ea022ac3.jpg
#   inflating: /kaggle/working/dataset/mousse/2949221294_5e9a730a7b.jpg
#   inflating: /kaggle/working/dataset/mousse/1283939911_8de6f16389.jpg
#   inflating: /kaggle/working/dataset/mousse/2619034307_d64f63156f.jpg
#   inflating: /kaggle/working/dataset/mousse/2265932527_0779752e19.jpg
#   inflating: /kaggle/working/dataset/mousse/3804041761_ee26ea4025.jpg
#   inflating: /kaggle/working/dataset/mousse/2251316234_8a6578c4cb.jpg
#   inflating: /kaggle/working/dataset/mousse/2522667474_fd04fc5850.jpg
#   inflating: /kaggle/working/dataset/mousse/3041876781_2afb480b22.jpg
#   inflating: /kaggle/working/dataset/mousse/3189859825_45395e99c2.jpg
#   inflating: /kaggle/working/dataset/mousse/3621282991_2f8bca6b24.jpg
#   inflating: /kaggle/working/dataset/mousse/3387784671_49192349d6.jpg
#   inflating: /kaggle/working/dataset/mousse/3518467712_49ac8dd98e.jpg
#   inflating: /kaggle/working/dataset/mousse/2158916987_9eec5e2dea.jpg
#   inflating: /kaggle/working/dataset/mousse/4146367935_2167ac90cf.jpg
#   inflating: /kaggle/working/dataset/mousse/2265911801_c524ef8d31.jpg
#   inflating: /kaggle/working/dataset/mousse/1284830332_edb7ffa3e3.jpg
#   inflating: /kaggle/working/dataset/mousse/2519748338_662c40b80e.jpg
#   inflating: /kaggle/working/dataset/mousse/2554893067_8f9bfeeae7.jpg
#   inflating: /kaggle/working/dataset/mousse/2527538343_72a386c944.jpg
#   inflating: /kaggle/working/dataset/mousse/526235591_918f516a3d.jpg
#   inflating: /kaggle/working/dataset/mousse/1812456481_bdec2fcaa5.jpg
#   inflating: /kaggle/working/dataset/mousse/4142477418_2416fc75bf.jpg
#   inflating: /kaggle/working/dataset/mousse/2940892461_e455b1e8e0.jpg
#   inflating: /kaggle/working/dataset/mousse/2699655051_1f42de4aa4.jpg
#   inflating: /kaggle/working/dataset/mousse/3692735218_7037f750f1.jpg
#   inflating: /kaggle/working/dataset/mousse/3229771107_d455272326.jpg
#   inflating: /kaggle/working/dataset/mousse/3575506840_8c4d4c7545.jpg
#   inflating: /kaggle/working/dataset/mousse/816973836_08280c36f3.jpg
#   inflating: /kaggle/working/dataset/mousse/4097345267_140b03e922.jpg
#   inflating: /kaggle/working/dataset/mousse/515816572_b673c77313.jpg
#   inflating: /kaggle/working/dataset/mousse/3316417880_4736585a6e.jpg
#   inflating: /kaggle/working/dataset/mousse/4124759513_a14d9a302b.jpg
#   inflating: /kaggle/working/dataset/mousse/3821143673_0409d82615.jpg
#   inflating: /kaggle/working/dataset/mousse/397029873_4a5814e87d.jpg
#   inflating: /kaggle/working/dataset/mousse/3085512119_8bf1577a87.jpg
#   inflating: /kaggle/working/dataset/mousse/2387531346_43a5638dac.jpg
#   inflating: /kaggle/working/dataset/mousse/2581617008_7dd424fa2d.jpg
#   inflating: /kaggle/working/dataset/mousse/3680322998_c4695b1485.jpg
#   inflating: /kaggle/working/dataset/mousse/2194113665_b6938d64a3.jpg
#   inflating: /kaggle/working/dataset/mousse/2058811489_084b29b2f9.jpg
#   inflating: /kaggle/working/dataset/mousse/76476519_4f28418fc4.jpg
#   inflating: /kaggle/working/dataset/mousse/3997341114_4399f24c02.jpg
#   inflating: /kaggle/working/dataset/mousse/2465676388_1742f29699.jpg
#   inflating: /kaggle/working/dataset/mousse/2076228529_4b086045fa.jpg
#   inflating: /kaggle/working/dataset/mousse/2182556696_291dffd823.jpg
#   inflating: /kaggle/working/dataset/mousse/3495280584_b0e578c513.jpg
#   inflating: /kaggle/working/dataset/mousse/2303359239_9ca8861f40.jpg
#   inflating: /kaggle/working/dataset/mousse/211959402_54bc5f486a.jpg
#   inflating: /kaggle/working/dataset/mousse/2598382966_02a9f11805.jpg
#   inflating: /kaggle/working/dataset/mousse/2310627815_553dbf70dc.jpg
#   inflating: /kaggle/working/dataset/mousse/2347031171_3228a7f5a7.jpg
#   inflating: /kaggle/working/dataset/mousse/2836188670_8e547fec03.jpg
#   inflating: /kaggle/working/dataset/mousse/4119745015_101699e588.jpg
#   inflating: /kaggle/working/dataset/mousse/2295173008_bf446f399b.jpg
#   inflating: /kaggle/working/dataset/mousse/83924358_b8badcbc4c.jpg
#   inflating: /kaggle/working/dataset/mousse/4069755498_02e1d0a657.jpg
#   inflating: /kaggle/working/dataset/mousse/2651301416_4cff09abbf.jpg
#   inflating: /kaggle/working/dataset/mousse/4058139213_03e02985fc.jpg
#   inflating: /kaggle/working/dataset/mousse/2865086898_df10a2c38e.jpg
#   inflating: /kaggle/working/dataset/mousse/2593661986_049dfb9265.jpg
#   inflating: /kaggle/working/dataset/mousse/369384976_9a3abc77e6.jpg
#   inflating: /kaggle/working/dataset/mousse/2991467002_2f1533c4b8.jpg
#   inflating: /kaggle/working/dataset/mousse/4199201897_5af12ebe49.jpg
#   inflating: /kaggle/working/dataset/mousse/53496642_e88cf00188.jpg
#   inflating: /kaggle/working/dataset/mousse/2556258351_c4afe71041.jpg
#   inflating: /kaggle/working/dataset/mousse/2130480686_f404c25706.jpg
#   inflating: /kaggle/working/dataset/mousse/2118197970_d8011d1288.jpg
#   inflating: /kaggle/working/dataset/mousse/1875179291_65a29ce58f.jpg
#   inflating: /kaggle/working/dataset/mousse/187011988_8a2c981f7b.jpg
#   inflating: /kaggle/working/dataset/mousse/3332525814_5ca80d1f82.jpg
#   inflating: /kaggle/working/dataset/mousse/12856678_a5278577ec.jpg
#   inflating: /kaggle/working/dataset/mousse/4054293932_ca04af8418.jpg
#   inflating: /kaggle/working/dataset/mousse/3966114745_85ba0a55c8.jpg
#   inflating: /kaggle/working/dataset/mousse/1606037441_b4a96c9149.jpg
#   inflating: /kaggle/working/dataset/mousse/3306565733_e6f234e7eb.jpg
#   inflating: /kaggle/working/dataset/mousse/2879057617_59aba3c230.jpg
#   inflating: /kaggle/working/dataset/mousse/3293417358_3175473f2c.jpg
#   inflating: /kaggle/working/dataset/mousse/3176778586_2b39840991.jpg
#   inflating: /kaggle/working/dataset/mousse/3514049316_63d557314c.jpg
#   inflating: /kaggle/working/dataset/mousse/4146581101_ba0f3901ef.jpg
#   inflating: /kaggle/working/dataset/mousse/1828283596_6cf3da6680.jpg
#   inflating: /kaggle/working/dataset/mousse/4034629659_43d55f363b.jpg
#   inflating: /kaggle/working/dataset/mousse/3449001941_90caa8eb32.jpg
#   inflating: /kaggle/working/dataset/mousse/3049193943_e44a8c874d.jpg
#   inflating: /kaggle/working/dataset/mousse/2216194950_7899e0a31b.jpg
#   inflating: /kaggle/working/dataset/mousse/2769139359_e950f76221.jpg
#   inflating: /kaggle/working/dataset/mousse/2992335400_b41ddb9f8f.jpg
#   inflating: /kaggle/working/dataset/mousse/3226220135_3d799b853c.jpg
#   inflating: /kaggle/working/dataset/mousse/2887785525_138f336d3b.jpg
#   inflating: /kaggle/working/dataset/mousse/4091421744_77cde24af4.jpg
#   inflating: /kaggle/working/dataset/mousse/3983549134_33c22b6dd3.jpg
#   inflating: /kaggle/working/dataset/mousse/3937770903_209606c19f.jpg
#   inflating: /kaggle/working/dataset/mousse/1536189149_6a8782554c.jpg
#   inflating: /kaggle/working/dataset/mousse/280528337_8efa3c57e4.jpg
#   inflating: /kaggle/working/dataset/mousse/3842171884_35292742d3.jpg
#   inflating: /kaggle/working/dataset/mousse/2774074697_b81f42f6c7.jpg
#   inflating: /kaggle/working/dataset/mousse/3542863586_1570d91462.jpg
#   inflating: /kaggle/working/dataset/mousse/2062816065_e822a3e38b.jpg
#   inflating: /kaggle/working/dataset/mousse/2139164301_65012938de.jpg
#   inflating: /kaggle/working/dataset/mousse/223474120_99fa982cba.jpg
#   inflating: /kaggle/working/dataset/mousse/4037415492_d8458a1433.jpg
#   inflating: /kaggle/working/dataset/mousse/3324885856_1f1a1bb02e.jpg
#   inflating: /kaggle/working/dataset/mousse/515314192_2cabfb4364.jpg
#   inflating: /kaggle/working/dataset/mousse/3517657329_7a44e01756.jpg
#   inflating: /kaggle/working/dataset/mousse/2262440454_403e795f24.jpg
#   inflating: /kaggle/working/dataset/mousse/2969359868_0aabd78183.jpg
#   inflating: /kaggle/working/dataset/mousse/3732413220_74b5c8581e.jpg
#   inflating: /kaggle/working/dataset/mousse/2759644620_de9e5e846b.jpg
#   inflating: /kaggle/working/dataset/mousse/2265921017_37d295c425.jpg
#   inflating: /kaggle/working/dataset/mousse/3263089714_32195e7309.jpg
#   inflating: /kaggle/working/dataset/mousse/2882151264_4389295000.jpg
#   inflating: /kaggle/working/dataset/mousse/2469422139_d39b963acb.jpg
#   inflating: /kaggle/working/dataset/mousse/2449910438_739baa5f82.jpg
#   inflating: /kaggle/working/dataset/mousse/1520977527_a6e52bf3a9.jpg
#   inflating: /kaggle/working/dataset/mousse/4119741693_2b8c1800b5.jpg
#   inflating: /kaggle/working/dataset/mousse/2276877112_85572cf026.jpg
#   inflating: /kaggle/working/dataset/mousse/2580839012_670b4c4303.jpg
#   inflating: /kaggle/working/dataset/mousse/4235936647_97c588c24d.jpg
#   inflating: /kaggle/working/dataset/mousse/3442052008_f5b8868779.jpg
#   inflating: /kaggle/working/dataset/mousse/2276930822_51e570077c.jpg
#   inflating: /kaggle/working/dataset/mousse/2844888433_d4af48e275.jpg
#   inflating: /kaggle/working/dataset/mousse/72871224_3e9bd3a180.jpg
#   inflating: /kaggle/working/dataset/mousse/2880176027_dc774caf1e.jpg
#   inflating: /kaggle/working/dataset/mousse/2931107495_bd73b8688a.jpg
#   inflating: /kaggle/working/dataset/mousse/2299217269_c560268d10.jpg
#   inflating: /kaggle/working/dataset/mousse/2615010955_5d2782cb4c.jpg
#   inflating: /kaggle/working/dataset/mousse/3753249690_dc6ba074f6.jpg
#   inflating: /kaggle/working/dataset/mousse/458920520_5fb23f579f.jpg
#   inflating: /kaggle/working/dataset/mousse/1736820228_a04043ff3a.jpg
#   inflating: /kaggle/working/dataset/mousse/2778988913_d63fc8717d.jpg
#   inflating: /kaggle/working/dataset/mousse/4067495833_9bc3a0449b.jpg
#   inflating: /kaggle/working/dataset/mousse/106863084_a062c8a60e.jpg
#   inflating: /kaggle/working/dataset/mousse/288268421_2b5769ade3.jpg
#   inflating: /kaggle/working/dataset/mousse/2083713742_29a56b5a11.jpg
#   inflating: /kaggle/working/dataset/mousse/3005940286_d9a0bbef73.jpg
#   inflating: /kaggle/working/dataset/mousse/2774074815_b46e903f64.jpg
#   inflating: /kaggle/working/dataset/mousse/2949222270_39a5b3d561.jpg
#   inflating: /kaggle/working/dataset/mousse/459077121_fce262a111.jpg
#   inflating: /kaggle/working/dataset/mousse/2528358512_c92430e80f.jpg
#   inflating: /kaggle/working/dataset/mousse/1487902344_9669a696c1.jpg
#   inflating: /kaggle/working/dataset/mousse/321885804_d8cf7ca0cc.jpg
#   inflating: /kaggle/working/dataset/mousse/2799426789_9bbbe24273.jpg
#   inflating: /kaggle/working/dataset/mousse/1873929433_b73715f5f6.jpg
#   inflating: /kaggle/working/dataset/mousse/3058709850_8dfff88b6b.jpg
#   inflating: /kaggle/working/dataset/mousse/3143506905_b77a76d958.jpg
#   inflating: /kaggle/working/dataset/mousse/2674102544_1a8ecc5b2b.jpg
#   inflating: /kaggle/working/dataset/Cheops/2761432763_7d15a6e72a.jpg
#   inflating: /kaggle/working/dataset/Cheops/62091267_fb40a1629c.jpg
#   inflating: /kaggle/working/dataset/Cheops/2746668700_fc83779b3e.jpg
#   inflating: /kaggle/working/dataset/Cheops/415050889_8a412d0597.jpg
#   inflating: /kaggle/working/dataset/Cheops/2178866516_ea36360c25.jpg
#   inflating: /kaggle/working/dataset/Cheops/2288584629_dd5d531734.jpg
#   inflating: /kaggle/working/dataset/Cheops/3041121459_611ce14f2c.jpg
#   inflating: /kaggle/working/dataset/Cheops/2874552439_2a3a978da3.jpg
#   inflating: /kaggle/working/dataset/Cheops/344027093_b09ff4e853.jpg
#   inflating: /kaggle/working/dataset/Cheops/344028957_56ebee9c70.jpg
#   inflating: /kaggle/working/dataset/Cheops/88990551_a2e9d86d60.jpg
#   inflating: /kaggle/working/dataset/Cheops/2897825723_319fd1741c.jpg
#   inflating: /kaggle/working/dataset/Cheops/3174158965_6fece7108b.jpg
#   inflating: /kaggle/working/dataset/Cheops/2118568270_ba394b7171.jpg
#   inflating: /kaggle/working/dataset/Cheops/280949236_a0e71d8954.jpg
#   inflating: /kaggle/working/dataset/Cheops/2118245006_520bb33ff2.jpg
#   inflating: /kaggle/working/dataset/Cheops/305900957_ca18a620e1.jpg
#   inflating: /kaggle/working/dataset/Cheops/1351418109_b3de32f7cc.jpg
#   inflating: /kaggle/working/dataset/Cheops/1407293398_46bf2764aa.jpg
#   inflating: /kaggle/working/dataset/Cheops/344025148_4b1a067648.jpg
#   inflating: /kaggle/working/dataset/Cheops/55710285_3d7587f374.jpg
#   inflating: /kaggle/working/dataset/Cheops/89606370_ec0dcee447.jpg
#   inflating: /kaggle/working/dataset/Cheops/3650034871_f147f6c6c9.jpg
#   inflating: /kaggle/working/dataset/Cheops/55708600_202d9ab5f8.jpg
#   inflating: /kaggle/working/dataset/Cheops/3044492515_14aabab4a5.jpg
#   inflating: /kaggle/working/dataset/Cheops/3044500235_c71c5dce73.jpg
#   inflating: /kaggle/working/dataset/Cheops/203416433_a1c26f4fb8.jpg
#   inflating: /kaggle/working/dataset/Cheops/3261180980_2b63a4bc89.jpg
#   inflating: /kaggle/working/dataset/Cheops/3593440986_601070223a.jpg
#   inflating: /kaggle/working/dataset/Cheops/3096342038_93072a9215.jpg
#   inflating: /kaggle/working/dataset/Cheops/3528143307_aeecb32e23.jpg
#   inflating: /kaggle/working/dataset/Cheops/2953534073_af1f7e5182.jpg
#   inflating: /kaggle/working/dataset/Cheops/3650034825_1f3d746608.jpg
#   inflating: /kaggle/working/dataset/Cheops/2124964433_c2491ea2b6.jpg
#   inflating: /kaggle/working/dataset/Cheops/2426531664_5fb9ea590c.jpg
#   inflating: /kaggle/working/dataset/Cheops/336536992_92a58ac45d.jpg
#   inflating: /kaggle/working/dataset/Cheops/2431185562_52957018e9.jpg
#   inflating: /kaggle/working/dataset/Cheops/2189168259_c59d06a256.jpg
#   inflating: /kaggle/working/dataset/Cheops/3335680689_e97ea25505.jpg
#   inflating: /kaggle/working/dataset/Cheops/2634615378_c3edd44383.jpg
#   inflating: /kaggle/working/dataset/Cheops/552211594_091d084a98.jpg
#   inflating: /kaggle/working/dataset/Cheops/2959579262_7d48e30726.jpg
#   inflating: /kaggle/working/dataset/Cheops/3500917573_b020a088af.jpg
#   inflating: /kaggle/working/dataset/Cheops/2081450066_37d536ca2c.jpg
#   inflating: /kaggle/working/dataset/Cheops/3414401819_c17dfdc26f.jpg
#   inflating: /kaggle/working/dataset/Cheops/3600454940_06edd1e040.jpg
#   inflating: /kaggle/working/dataset/Cheops/3094973863_f43068a46c.jpg
#   inflating: /kaggle/working/dataset/Cheops/3261191934_8debfa5f99.jpg
#   inflating: /kaggle/working/dataset/Cheops/3402624134_fdcb53a5d2.jpg
#   inflating: /kaggle/working/dataset/Cheops/2753020265_9b43bcb7e2.jpg
#   inflating: /kaggle/working/dataset/Cheops/2118439372_9ce0f16c1f.jpg
#   inflating: /kaggle/working/dataset/Cheops/2432899227_d7a702214a.jpg
#   inflating: /kaggle/working/dataset/Cheops/2326272005_ee953338c3.jpg
#   inflating: /kaggle/working/dataset/Cheops/2028609036_5f80a895a6.jpg
#   inflating: /kaggle/working/dataset/Cheops/2634609346_dc1e6ae4b6.jpg
#   inflating: /kaggle/working/dataset/Cheops/1771433_08fa2ae45f.jpg
#   inflating: /kaggle/working/dataset/Cheops/189554317_2e32be7362.jpg
#   inflating: /kaggle/working/dataset/Cheops/336537030_a15c1f534b.jpg
#   inflating: /kaggle/working/dataset/Cheops/2347083369_ab3aa9d309.jpg
#   inflating: /kaggle/working/dataset/Cheops/3267544998_aba0b22e43.jpg
#   inflating: /kaggle/working/dataset/Cheops/2117486739_73f0b2c048.jpg
#   inflating: /kaggle/working/dataset/Cheops/2302306331_828efd4700.jpg
#   inflating: /kaggle/working/dataset/Cheops/478164644_28afbb2729.jpg
#   inflating: /kaggle/working/dataset/Cheops/3101114974_4fd703c4e4.jpg
#   inflating: /kaggle/working/dataset/Cheops/2631422145_ccdb2a4ccd.jpg
#   inflating: /kaggle/working/dataset/Cheops/457481084_89e9211000.jpg
#   inflating: /kaggle/working/dataset/Cheops/542475693_5ae947438f.jpg
#   inflating: /kaggle/working/dataset/Cheops/2476381511_dd062a482d.jpg
#   inflating: /kaggle/working/dataset/Cheops/3593435318_7f8ec4878e.jpg
#   inflating: /kaggle/working/dataset/Cheops/2205914003_55d8aa81a6.jpg
#   inflating: /kaggle/working/dataset/Cheops/2373636358_863e17e6ee.jpg
#   inflating: /kaggle/working/dataset/Cheops/3600415384_18bbbf931e.jpg
#   inflating: /kaggle/working/dataset/Cheops/478177011_2771ce6aa6.jpg
#   inflating: /kaggle/working/dataset/Cheops/305900798_c82b62bffb.jpg
#   inflating: /kaggle/working/dataset/Cheops/149551934_dacf20d171.jpg
#   inflating: /kaggle/working/dataset/Cheops/2117775643_4965ef7520.jpg
#   inflating: /kaggle/working/dataset/Cheops/3626396775_4321674945.jpg
#   inflating: /kaggle/working/dataset/Cheops/2864481453_43791cea32.jpg
#   inflating: /kaggle/working/dataset/Cheops/187912439_75548d649f.jpg
#   inflating: /kaggle/working/dataset/Cheops/2226253663_bd556c2c5b.jpg
#   inflating: /kaggle/working/dataset/Cheops/3095825240_71b15d24c3.jpg
#   inflating: /kaggle/working/dataset/Cheops/2112607883_516862e5a3.jpg
#   inflating: /kaggle/working/dataset/Cheops/140901026_7bfa02311f.jpg
#   inflating: /kaggle/working/dataset/Cheops/2117807937_a69092d2b3.jpg
#   inflating: /kaggle/working/dataset/Cheops/2557822905_81f5021eb3.jpg
#   inflating: /kaggle/working/dataset/Cheops/2118053846_bde77654b7.jpg
#   inflating: /kaggle/working/dataset/Cheops/3724750701_0371b4dee3.jpg
#   inflating: /kaggle/working/dataset/Cheops/3199681592_5a062f6e28.jpg
#   inflating: /kaggle/working/dataset/Cheops/3174837538_478e813e20.jpg
#   inflating: /kaggle/working/dataset/Cheops/56352771_9988fc6ade.jpg
#   inflating: /kaggle/working/dataset/Cheops/2959640300_9dd6ee59da.jpg
#   inflating: /kaggle/working/dataset/Cheops/2117800721_0c597babe7.jpg
#   inflating: /kaggle/working/dataset/Cheops/184800743_a3f5849aa6.jpg
#   inflating: /kaggle/working/dataset/Cheops/2117699951_70c4441934.jpg
#   inflating: /kaggle/working/dataset/Cheops/2222944083_c3042c56b6.jpg
#   inflating: /kaggle/working/dataset/Cheops/1306208893_cf962bfcb2.jpg
#   inflating: /kaggle/working/dataset/Cheops/2117723007_8c7f264f52.jpg
#   inflating: /kaggle/working/dataset/Cheops/2110846815_80dca587cd.jpg
#   inflating: /kaggle/working/dataset/Cheops/2118574956_e50890a68f.jpg
#   inflating: /kaggle/working/dataset/Cheops/3232595710_6fbff11db4.jpg
#   inflating: /kaggle/working/dataset/Cheops/6158000_5e86f0da26.jpg
#   inflating: /kaggle/working/dataset/Cheops/287772599_aae0eba0e0.jpg
#   inflating: /kaggle/working/dataset/Cheops/326266706_503443fb26.jpg
#   inflating: /kaggle/working/dataset/Cheops/299588249_eadb16355a.jpg
#   inflating: /kaggle/working/dataset/Cheops/457478080_f53c566c2f.jpg
#   inflating: /kaggle/working/dataset/Cheops/478157426_53aca6b907.jpg
#   inflating: /kaggle/working/dataset/Cheops/126894478_c2288358ab.jpg
#   inflating: /kaggle/working/dataset/Cheops/98717302_76ae7fcdd1.jpg
#   inflating: /kaggle/working/dataset/Cheops/3299190447_631d4eb877.jpg
#   inflating: /kaggle/working/dataset/Cheops/197418230_73663ee58d.jpg
#   inflating: /kaggle/working/dataset/Cheops/2118242532_6eafaf5305.jpg
#   inflating: /kaggle/working/dataset/Cheops/3415244110_0b3792c7ee.jpg
#   inflating: /kaggle/working/dataset/Cheops/437688201_d899a1500e.jpg
#   inflating: /kaggle/working/dataset/Cheops/3551526168_800914d39e.jpg
#   inflating: /kaggle/working/dataset/Cheops/2321310174_3351173105.jpg
#   inflating: /kaggle/working/dataset/Cheops/56351211_b5ae5f5507.jpg
#   inflating: /kaggle/working/dataset/Cheops/3466121931_dc5fc8857f.jpg
#   inflating: /kaggle/working/dataset/Cheops/3615587663_b169863352.jpg
#   inflating: /kaggle/working/dataset/Cheops/3649291389_bcbef14a0b.jpg
#   inflating: /kaggle/working/dataset/Cheops/362561665_b95d360308.jpg
#   inflating: /kaggle/working/dataset/Cheops/962165538_eb2020f55c.jpg
#   inflating: /kaggle/working/dataset/Cheops/1352332372_a9875a8794.jpg
#   inflating: /kaggle/working/dataset/Cheops/2523147120_d2e3578353.jpg
#   inflating: /kaggle/working/dataset/Cheops/2746577104_037f30f882.jpg
#   inflating: /kaggle/working/dataset/Cheops/2624676687_d0eabd2b18.jpg
#   inflating: /kaggle/working/dataset/Cheops/2524131029_72f6e3de97.jpg
#   inflating: /kaggle/working/dataset/Cheops/891944222_62af0c092f.jpg
#   inflating: /kaggle/working/dataset/Cheops/3224549055_76603b7c1e.jpg
#   inflating: /kaggle/working/dataset/Cheops/389166244_1ebcde8be3.jpg
#   inflating: /kaggle/working/dataset/Cheops/2111638786_245815bdb2.jpg
#   inflating: /kaggle/working/dataset/Cheops/3049547997_371e47ccd9.jpg
#   inflating: /kaggle/working/dataset/Cheops/1101646997_b88a23815d.jpg
#   inflating: /kaggle/working/dataset/Cheops/3570619483_14ff461869.jpg
#   inflating: /kaggle/working/dataset/Cheops/632834559_2d879d5541.jpg
#   inflating: /kaggle/working/dataset/Cheops/2633837639_5f2f9065ed.jpg
#   inflating: /kaggle/working/dataset/Cheops/287144703_cc28f47cec.jpg
#   inflating: /kaggle/working/dataset/Cheops/3466937082_accd47a75d.jpg
#   inflating: /kaggle/working/dataset/Cheops/410867958_f2302f341a_o.jpg
#   inflating: /kaggle/working/dataset/Cheops/287144738_8f7857a33a.jpg
#   inflating: /kaggle/working/dataset/Cheops/2117770297_fb6520e7b6.jpg
#   inflating: /kaggle/working/dataset/Cheops/3217940259_45b1ebc427.jpg
#   inflating: /kaggle/working/dataset/Cheops/2828471677_dc3333b723.jpg
#   inflating: /kaggle/working/dataset/Cheops/3600416396_c63955ace8.jpg
#   inflating: /kaggle/working/dataset/Cheops/135194588_e76bbcbb81.jpg
#   inflating: /kaggle/working/dataset/Cheops/2118361446_91bf65185b.jpg
#   inflating: /kaggle/working/dataset/Cheops/432276196_7c8aaff765.jpg
#   inflating: /kaggle/working/dataset/Cheops/294873747_458c87c9dc.jpg
#   inflating: /kaggle/working/dataset/Cheops/2761526253_d0bdac848c.jpg
#   inflating: /kaggle/working/dataset/Cheops/3650034897_2276848bba.jpg
#   inflating: /kaggle/working/dataset/Cheops/140899594_38ce12a089.jpg
#   inflating: /kaggle/working/dataset/Cheops/2111618008_1b2b200bdf.jpg
#   inflating: /kaggle/working/dataset/Cheops/184871993_1db7c6cf7e.jpg
#   inflating: /kaggle/working/dataset/Cheops/31651393_906da2d9e2.jpg
#   inflating: /kaggle/working/dataset/Cheops/992402218_8d88ecdb87.jpg
#   inflating: /kaggle/working/dataset/Cheops/2118069526_f6418d7368.jpg
#   inflating: /kaggle/working/dataset/Cheops/3425263748_41d2c39e6b.jpg
#   inflating: /kaggle/working/dataset/Cheops/2853017059_b7592c1607.jpg
#   inflating: /kaggle/working/dataset/Cheops/88990577_31aa3b48a6.jpg
#   inflating: /kaggle/working/dataset/Cheops/89842302_7a646d06f3.jpg
#   inflating: /kaggle/working/dataset/Cheops/3235540710_b84d02d188.jpg
#   inflating: /kaggle/working/dataset/Cheops/3005684532_f894a62a1a.jpg
#   inflating: /kaggle/working/dataset/Cheops/2432561002_7f67387839.jpg
#   inflating: /kaggle/working/dataset/Cheops/2865314686_cb614e3e1a.jpg
#   inflating: /kaggle/working/dataset/Cheops/2118556594_dda5c130ab.jpg
#   inflating: /kaggle/working/dataset/Cheops/2303103690_63573e7e66.jpg
#   inflating: /kaggle/working/dataset/Cheops/3329808638_48c47747e5.jpg
#   inflating: /kaggle/working/dataset/Cheops/1869478357_bb1394523a.jpg
#   inflating: /kaggle/working/dataset/Cheops/3715330446_f535c22d4b.jpg
#   inflating: /kaggle/working/dataset/Cheops/2852946895_165f864161.jpg
#   inflating: /kaggle/working/dataset/Cheops/287143993_f95fee677a.jpg
#   inflating: /kaggle/working/dataset/Cheops/4219525_643a0aa5f9.jpg
#   inflating: /kaggle/working/dataset/Cheops/2326462075_bb17fed0bb.jpg
#   inflating: /kaggle/working/dataset/Cheops/26650373_cdd3ae1fb7.jpg
#   inflating: /kaggle/working/dataset/Cheops/2846064500_9de175773d.jpg
#   inflating: /kaggle/working/dataset/Cheops/296782353_516bc03413.jpg
#   inflating: /kaggle/working/dataset/Cheops/2965781103_e6a62784cf.jpg
#   inflating: /kaggle/working/dataset/Cheops/2824311587_60f675fbde.jpg
#   inflating: /kaggle/working/dataset/Cheops/1577553781_1c661d6be8.jpg
#   inflating: /kaggle/working/dataset/Cheops/2343608534_92a93f4a1b.jpg
#   inflating: /kaggle/working/dataset/Cheops/3592624607_8670120625.jpg
#   inflating: /kaggle/working/dataset/Cheops/2433895025_601134d8a0.jpg
#   inflating: /kaggle/working/dataset/Cheops/1420249785_aa25f3cc42.jpg
#   inflating: /kaggle/working/dataset/Cheops/2434717146_8f90c521f5.jpg
#   inflating: /kaggle/working/dataset/Cheops/1407294778_0c25136232.jpg
#   inflating: /kaggle/working/dataset/Cheops/3065835782_c78ffe5402.jpg
#   inflating: /kaggle/working/dataset/Cheops/2117806127_8de742f4f1.jpg
#   inflating: /kaggle/working/dataset/Cheops/1639212969_a510e9e0dc.jpg
#   inflating: /kaggle/working/dataset/Cheops/2373636352_8d7bc8010a.jpg
#   inflating: /kaggle/working/dataset/Cheops/1863549736_e67857a18d.jpg
#   inflating: /kaggle/working/dataset/Cheops/3912223160_3aa722172f.jpg
#   inflating: /kaggle/working/dataset/Cheops/2146933306_43ec9314e0.jpg
#   inflating: /kaggle/working/dataset/Cheops/3626393701_f47c39e01e.jpg
#   inflating: /kaggle/working/dataset/Cheops/55708762_9df22ddca6.jpg
#   inflating: /kaggle/working/dataset/Cheops/478167068_1044033d6c.jpg
#   inflating: /kaggle/working/dataset/Cheops/632823415_9bc31cfe22.jpg
#   inflating: /kaggle/working/dataset/Cheops/3573446108_9122e9f883.jpg
#   inflating: /kaggle/working/dataset/Cheops/3707571104_b21a503f1d.jpg
#   inflating: /kaggle/working/dataset/Cheops/3386600745_4ffaf946ec.jpg
#   inflating: /kaggle/working/dataset/Cheops/2986464725_c951c4b092.jpg
#   inflating: /kaggle/working/dataset/Cheops/2235112711_b015b7c1f2.jpg
#   inflating: /kaggle/working/dataset/stately home/2934001415_ee6d261a35.jpg
#   inflating: /kaggle/working/dataset/stately home/2912956318_1580dbe7e8.jpg
#   inflating: /kaggle/working/dataset/stately home/1567905586_2991e869fa.jpg
#   inflating: /kaggle/working/dataset/stately home/2895145252_09193b126a.jpg
#   inflating: /kaggle/working/dataset/stately home/1566984591_4ef7a0102a.jpg
#   inflating: /kaggle/working/dataset/stately home/155788970_5f83e921a9.jpg
#   inflating: /kaggle/working/dataset/stately home/2685784178_645195466c.jpg
#   inflating: /kaggle/working/dataset/stately home/2771741474_f73096b1b9.jpg
#   inflating: /kaggle/working/dataset/stately home/1567947426_73ec2c46c1.jpg
#   inflating: /kaggle/working/dataset/stately home/2517012604_d4d0050b70.jpg
#   inflating: /kaggle/working/dataset/stately home/427019531_1c2a9fc4eb.jpg
#   inflating: /kaggle/working/dataset/stately home/254733479_20cf47eb7e.jpg
#   inflating: /kaggle/working/dataset/stately home/1250626884_2b2b20e551.jpg
#   inflating: /kaggle/working/dataset/stately home/3188514712_29d3b35049.jpg
#   inflating: /kaggle/working/dataset/stately home/2981953996_ae90f84823.jpg
#   inflating: /kaggle/working/dataset/stately home/3159487733_912446faf5.jpg
#   inflating: /kaggle/working/dataset/stately home/2521103890_65a18d3c4e.jpg
#   inflating: /kaggle/working/dataset/stately home/159852833_07d097358c.jpg
#   inflating: /kaggle/working/dataset/stately home/2704652590_bd3e973fa8.jpg
#   inflating: /kaggle/working/dataset/stately home/106353447_c990e1f661.jpg
#   inflating: /kaggle/working/dataset/stately home/266212670_8ca4e7e7f5.jpg
#   inflating: /kaggle/working/dataset/stately home/2606929752_3f327f9e85.jpg
#   inflating: /kaggle/working/dataset/stately home/2942489442_d325aaac9b.jpg
#   inflating: /kaggle/working/dataset/stately home/2778885896_e409187bf1.jpg
#   inflating: /kaggle/working/dataset/stately home/456897838_8dbc1e1c15.jpg
#   inflating: /kaggle/working/dataset/stately home/511733973_9806fd9534.jpg
#   inflating: /kaggle/working/dataset/stately home/893838350_edd4873306.jpg
#   inflating: /kaggle/working/dataset/stately home/3160297240_901f60740f.jpg
#   inflating: /kaggle/working/dataset/stately home/2980783819_d4fd546170.jpg
#   inflating: /kaggle/working/dataset/stately home/2814737545_1930ce9394.jpg
#   inflating: /kaggle/working/dataset/stately home/2843012403_aa1a6e96a4.jpg
#   inflating: /kaggle/working/dataset/stately home/840646560_02c0fb495e.jpg
#   inflating: /kaggle/working/dataset/stately home/3199507415_17a49646a5.jpg
#   inflating: /kaggle/working/dataset/stately home/2143984931_04f5fd4c0b.jpg
#   inflating: /kaggle/working/dataset/stately home/2367423002_f1681849d9.jpg
#   inflating: /kaggle/working/dataset/stately home/2824849157_9da970610e.jpg
#   inflating: /kaggle/working/dataset/stately home/3024382311_48f345abb1.jpg
#   inflating: /kaggle/working/dataset/stately home/1429669130_d07a99d27b_o.jpg
#   inflating: /kaggle/working/dataset/stately home/70628372_8ba14343d3.jpg
#   inflating: /kaggle/working/dataset/stately home/2606945410_0068da98c6.jpg
#   inflating: /kaggle/working/dataset/stately home/1698978990_8e473e228e.jpg
#   inflating: /kaggle/working/dataset/stately home/2605795844_89f9ff6a7d.jpg
#   inflating: /kaggle/working/dataset/stately home/393390140_12dd38eb46.jpg
#   inflating: /kaggle/working/dataset/stately home/2805106457_bf6981785f.jpg
#   inflating: /kaggle/working/dataset/stately home/337308765_cb0297499e.jpg
#   inflating: /kaggle/working/dataset/stately home/2870912953_d172ae633f.jpg
#   inflating: /kaggle/working/dataset/stately home/421933437_06046c9838.jpg
#   inflating: /kaggle/working/dataset/stately home/3159498353_e4a0a18211.jpg
#   inflating: /kaggle/working/dataset/stately home/1567013435_06727ce400.jpg
#   inflating: /kaggle/working/dataset/stately home/3110033268_7c82879578.jpg
#   inflating: /kaggle/working/dataset/stately home/2432619104_8e55609781.jpg
#   inflating: /kaggle/working/dataset/stately home/2934859940_a4d551b124.jpg
#   inflating: /kaggle/working/dataset/stately home/3159494197_cb1c074241.jpg
#   inflating: /kaggle/working/dataset/stately home/1264990984_fc53790e33.jpg
#   inflating: /kaggle/working/dataset/stately home/406329145_83e4cce21b.jpg
#   inflating: /kaggle/working/dataset/stately home/2779158696_d4449a269b.jpg
#   inflating: /kaggle/working/dataset/stately home/2491786633_ed92e77852.jpg
#   inflating: /kaggle/working/dataset/stately home/2747502430_e7d3d01925.jpg
#   inflating: /kaggle/working/dataset/stately home/452104029_d96be5b94a.jpg
#   inflating: /kaggle/working/dataset/stately home/2879490419_9001578428.jpg
#   inflating: /kaggle/working/dataset/stately home/255154945_0cb2abf57d.jpg
#   inflating: /kaggle/working/dataset/stately home/2711407804_e081d2c1ba.jpg
#   inflating: /kaggle/working/dataset/stately home/2909215827_9979c33281.jpg
#   inflating: /kaggle/working/dataset/stately home/2894683146_082362fc58.jpg
#   inflating: /kaggle/working/dataset/stately home/3128188278_8650819a83.jpg
#   inflating: /kaggle/working/dataset/stately home/46246398_1c4a34b141.jpg
#   inflating: /kaggle/working/dataset/stately home/2387594620_5195db6150.jpg
#   inflating: /kaggle/working/dataset/stately home/3199518966_fdba70a5bd.jpg
#   inflating: /kaggle/working/dataset/stately home/219867587_3318f32aaf.jpg
#   inflating: /kaggle/working/dataset/stately home/2272121448_13d993da8b.jpg
#   inflating: /kaggle/working/dataset/stately home/2570386559_0c10d97073.jpg
#   inflating: /kaggle/working/dataset/stately home/450207149_7130d43244.jpg
#   inflating: /kaggle/working/dataset/stately home/2814712655_eed5390154.jpg
#   inflating: /kaggle/working/dataset/stately home/2491778388_11882970e7.jpg
#   inflating: /kaggle/working/dataset/stately home/2586552143_e1cd734ce3.jpg
#   inflating: /kaggle/working/dataset/stately home/476688401_e81296bb4a.jpg
#   inflating: /kaggle/working/dataset/stately home/2367413268_47857763ec.jpg
#   inflating: /kaggle/working/dataset/stately home/397951567_6194d3e83c.jpg
#   inflating: /kaggle/working/dataset/stately home/2367401844_f30faccf43.jpg
#   inflating: /kaggle/working/dataset/stately home/39674044_cdd31a8519.jpg
#   inflating: /kaggle/working/dataset/stately home/2797822458_80827ae851.jpg
#   inflating: /kaggle/working/dataset/stately home/749703329_1de77682d4.jpg
#   inflating: /kaggle/working/dataset/stately home/2644767403_3ba8cfc481.jpg
#   inflating: /kaggle/working/dataset/stately home/2347805474_8bb546106d.jpg
#   inflating: /kaggle/working/dataset/stately home/892970479_275797fc29.jpg
#   inflating: /kaggle/working/dataset/stately home/211710348_bdeb70e454.jpg
#   inflating: /kaggle/working/dataset/stately home/63490818_fa71fee613.jpg
#   inflating: /kaggle/working/dataset/stately home/473838074_962d356d7e.jpg
#   inflating: /kaggle/working/dataset/stately home/3147494005_32c62d0674.jpg
#   inflating: /kaggle/working/dataset/stately home/2271922069_9421b501d3.jpg
#   inflating: /kaggle/working/dataset/stately home/2346974115_fdb755c95f.jpg
#   inflating: /kaggle/working/dataset/stately home/3160325028_474ff3f230.jpg
#   inflating: /kaggle/working/dataset/stately home/291358979_57823bbf73.jpg
#   inflating: /kaggle/working/dataset/stately home/155789247_5eba4bb647.jpg
#   inflating: /kaggle/working/dataset/stately home/2489972895_1e3dfae085.jpg
#   inflating: /kaggle/working/dataset/stately home/132058809_8de6e45324.jpg
#   inflating: /kaggle/working/dataset/stately home/1247462343_eb80df5f7f.jpg
#   inflating: /kaggle/working/dataset/stately home/203820389_9015f4d7c1.jpg
#   inflating: /kaggle/working/dataset/stately home/224628156_9b1a27ddde.jpg
#   inflating: /kaggle/working/dataset/stately home/2814218684_441d9760f7.jpg
#   inflating: /kaggle/working/dataset/stately home/2916039720_603c33f830.jpg
#   inflating: /kaggle/working/dataset/stately home/389584286_5eb256af08.jpg
#   inflating: /kaggle/working/dataset/stately home/1279047820_646c11bdf6.jpg
#   inflating: /kaggle/working/dataset/stately home/2893844325_f7f0ceddd1.jpg
#   inflating: /kaggle/working/dataset/stately home/375684759_622e7aa755.jpg
#   inflating: /kaggle/working/dataset/stately home/2431805347_a3b178214d.jpg
#   inflating: /kaggle/working/dataset/stately home/3198576407_7b35ce2bec.jpg
#   inflating: /kaggle/working/dataset/stately home/2949902743_cb70fc5666.jpg
#   inflating: /kaggle/working/dataset/stately home/198906910_a5680ced50.jpg
#   inflating: /kaggle/working/dataset/stately home/2060019173_66974bfca8.jpg
#   inflating: /kaggle/working/dataset/stately home/755416268_945961865c.jpg
#   inflating: /kaggle/working/dataset/stately home/155788627_f7dcfb3465.jpg
#   inflating: /kaggle/working/dataset/stately home/2498153635_10423e7af7.jpg
#   inflating: /kaggle/working/dataset/stately home/2791681899_789d4c7055.jpg
#   inflating: /kaggle/working/dataset/stately home/2795331423_4d42045359.jpg
#   inflating: /kaggle/working/dataset/stately home/2391612349_ed9d99270d.jpg
#   inflating: /kaggle/working/dataset/stately home/2898181106_c5e5eb31dd.jpg
#   inflating: /kaggle/working/dataset/stately home/2912105141_6e0d5b1272.jpg
#   inflating: /kaggle/working/dataset/stately home/2475267879_671e82afe4.jpg
#   inflating: /kaggle/working/dataset/stately home/610901991_06648a9ae8.jpg
#   inflating: /kaggle/working/dataset/stately home/538563647_28f285675f.jpg
#   inflating: /kaggle/working/dataset/stately home/2111304795_86b8d972e7.jpg
#   inflating: /kaggle/working/dataset/stately home/2980783821_da0b60a8db.jpg
#   inflating: /kaggle/working/dataset/stately home/187401291_37243dfa1b.jpg
#   inflating: /kaggle/working/dataset/stately home/2230401628_ba6abbdf1c.jpg
#   inflating: /kaggle/working/dataset/stately home/2459320615_9418f3d50b.jpg
#   inflating: /kaggle/working/dataset/stately home/2743406073_e1499fa85c.jpg
#   inflating: /kaggle/working/dataset/stately home/2168646231_250a202db7.jpg
#   inflating: /kaggle/working/dataset/stately home/2476101476_d9a2281994.jpg
#   inflating: /kaggle/working/dataset/stately home/527620168_ec11dac414.jpg
#   inflating: /kaggle/working/dataset/stately home/10297942_8faafd407e.jpg
#   inflating: /kaggle/working/dataset/stately home/255153106_904281bd82.jpg
#   inflating: /kaggle/working/dataset/stately home/171569677_b009266c5c.jpg
#   inflating: /kaggle/working/dataset/stately home/2766875092_8eed2b85ac.jpg
#   inflating: /kaggle/working/dataset/stately home/2432632794_cc80884810.jpg
#   inflating: /kaggle/working/dataset/stately home/2830291632_0745b47ae6.jpg
#   inflating: /kaggle/working/dataset/stately home/1564510393_6721754dcf.jpg
#   inflating: /kaggle/working/dataset/stately home/2348119148_a7c594f35d.jpg
#   inflating: /kaggle/working/dataset/stately home/2155850851_3ae8b7501b.jpg
#   inflating: /kaggle/working/dataset/stately home/2583155653_aa19ca5d75.jpg
#   inflating: /kaggle/working/dataset/stately home/2503013480_2564d780c1.jpg
#   inflating: /kaggle/working/dataset/stately home/2851994506_c9406f0d6f.jpg
#   inflating: /kaggle/working/dataset/stately home/36344024_2a7292a684.jpg
#   inflating: /kaggle/working/dataset/stately home/2570455618_649c0dc8d6.jpg
#   inflating: /kaggle/working/dataset/stately home/2277081770_da7e1cbd09.jpg
#   inflating: /kaggle/working/dataset/stately home/1323468656_16607131f8.jpg
#   inflating: /kaggle/working/dataset/stately home/1310952645_c8d486af53.jpg
#   inflating: /kaggle/working/dataset/stately home/816229731_c5bf90dd06.jpg
#   inflating: /kaggle/working/dataset/stately home/3010383988_88bec9d5bc.jpg
#   inflating: /kaggle/working/dataset/stately home/85345756_337f7835ac.jpg
#   inflating: /kaggle/working/dataset/stately home/181556360_8bdfb048a4.jpg
#   inflating: /kaggle/working/dataset/stately home/2057215497_badc5f0e0e.jpg
#   inflating: /kaggle/working/dataset/stately home/2877647941_1e130c214f.jpg
#   inflating: /kaggle/working/dataset/stately home/2408241358_66e24f4688.jpg
#   inflating: /kaggle/working/dataset/stately home/2367425972_6f92500bef.jpg
#   inflating: /kaggle/working/dataset/stately home/1424872754_440e397547.jpg
#   inflating: /kaggle/working/dataset/stately home/2366583683_432d9573c2.jpg
#   inflating: /kaggle/working/dataset/stately home/2875475602_e063040ddb.jpg
#   inflating: /kaggle/working/dataset/stately home/2827533672_a58d8d373a.jpg
#   inflating: /kaggle/working/dataset/stately home/527791479_06e5990051.jpg
#   inflating: /kaggle/working/dataset/stately home/2556630270_92a63eda0f.jpg
#   inflating: /kaggle/working/dataset/stately home/127137492_76cc7ff882.jpg
#   inflating: /kaggle/working/dataset/stately home/2838534582_ce8a394590.jpg
#   inflating: /kaggle/working/dataset/stately home/54828801_c945940c0e.jpg
#   inflating: /kaggle/working/dataset/stately home/2456754030_a4b1bbf251.jpg
#   inflating: /kaggle/working/dataset/stately home/476672528_d3c37604ec.jpg
#   inflating: /kaggle/working/dataset/stately home/38285704_a450ea3ca8.jpg
#   inflating: /kaggle/working/dataset/stately home/2968193150_ab75f60b96.jpg
#   inflating: /kaggle/working/dataset/stately home/1117341603_0ea0a15925.jpg
#   inflating: /kaggle/working/dataset/stately home/2806547705_2b6fceacee.jpg
#   inflating: /kaggle/working/dataset/stately home/452476565_3d507c26f3.jpg
#   inflating: /kaggle/working/dataset/stately home/2493542092_82faf13765.jpg
#   inflating: /kaggle/working/dataset/stately home/2133700935_fe1bd428d3.jpg
#   inflating: /kaggle/working/dataset/stately home/2070922121_b925db8263.jpg
#   inflating: /kaggle/working/dataset/stately home/2974122916_8edb5dc749.jpg
#   inflating: /kaggle/working/dataset/stately home/2367410054_470beee144.jpg
#   inflating: /kaggle/working/dataset/stately home/3160327918_2c4c80f7f3.jpg
#   inflating: /kaggle/working/dataset/stately home/3122321757_0e2cc46bd1.jpg
#   inflating: /kaggle/working/dataset/stately home/2773292977_4ea144f28d.jpg
#   inflating: /kaggle/working/dataset/stately home/354985987_7cd32bfb64.jpg
#   inflating: /kaggle/working/dataset/stately home/155789537_fd46e3f451.jpg
#   inflating: /kaggle/working/dataset/stately home/2774518354_fcc13b807c.jpg
#   inflating: /kaggle/working/dataset/stately home/2702855688_a4ca6e0e41.jpg
#   inflating: /kaggle/working/dataset/stately home/2965600681_49f2a1a4a7.jpg
#   inflating: /kaggle/working/dataset/stately home/3082659985_9425fe2c8a.jpg
#   inflating: /kaggle/working/dataset/stately home/3204060844_831d78a168.jpg
#   inflating: /kaggle/working/dataset/stately home/488238877_61960db4e1.jpg
#   inflating: /kaggle/working/dataset/stately home/528290039_f163042327.jpg
#   inflating: /kaggle/working/dataset/stately home/3034945717_6fb22f1ce3.jpg
#   inflating: /kaggle/working/dataset/stately home/214866282_d909a6dc87.jpg
#   inflating: /kaggle/working/dataset/stately home/930523230_61e74c66eb.jpg
#   inflating: /kaggle/working/dataset/stately home/291711168_9b46be445e.jpg
#   inflating: /kaggle/working/dataset/stately home/2899092013_0e1673a034.jpg
#   inflating: /kaggle/working/dataset/stately home/2225238609_cf6d819de0.jpg
#   inflating: /kaggle/working/dataset/stately home/2947938374_0b5d633190.jpg
#   inflating: /kaggle/working/dataset/stately home/379940486_57bc113028.jpg
#   inflating: /kaggle/working/dataset/stately home/2518779636_c7df9a4929.jpg
#   inflating: /kaggle/working/dataset/stately home/1566586429_46419deebe.jpg
#   inflating: /kaggle/working/dataset/stately home/2788956917_3e1bafef26.jpg
#   inflating: /kaggle/working/dataset/stately home/1432115076_f9745c980c.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/2540641948_9566fc851f.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/379601344_79039bb17b.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/2648004700_370686f157.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/2912065305_39f00bc43a.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/40503128_78d09d1a19.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/2319299749_084a42c21f.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/2988503672_288afb0eac.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/431133403_411254bf7f.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/2627694160_032d056d53.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/1582545929_ac7d7157f3.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/366933107_3c28a8c7d7.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/781590311_24531f7da3.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/2748792820_8d6472c326.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/1037313041_20289a1ca9.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/66405271_a101850ca3.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/38027119_905228dff8.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/235297179_73b280f5f3.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/300005612_131c973ae5.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/1356123612_44b3e5f9af.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/1499045586_e5ee1f7ac5.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/2204288862_80034b5c5a.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/368353340_bf0d577090.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/1282027423_91dae25eca.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/2445646688_de5317e29f.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/2455234444_c58ef88a07.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/2266675271_7470d66f9e.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/180660845_17a30cdf67.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/1771662985_ae153429f6.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/542417331_b990413725.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/3139495334_b46cd151ef.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/542414121_aca3daf882.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/87660749_bc6cbcb4e9.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/2199063964_606e44c254.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/2203493783_e2f2febe50.jpg
#   inflating: /kaggle/working/dataset/Moorish arch/3059090635_2a641e1e9e.jpg
# ...
#   inflating: /kaggle/working/dataset/toy box/3226820133_28e5c9199d.jpg
#   inflating: /kaggle/working/dataset/toy box/1434528483_d1e6879d7b.jpg
#   inflating: /kaggle/working/dataset/toy box/2530066978_12982b93e4.jpg
#   inflating: /kaggle/working/dataset/toy box/264875240_83ad438ce3.jpg
#   inflating: /kaggle/working/dataset/toy box/2543494031_ef72a0c502.jpg
#   inflating: /kaggle/working/dataset/toy box/2122114078_513414c28b.jpg
#   inflating: /kaggle/working/dataset/toy box/2970256119_e10800a9c6.jpg
#   inflating: /kaggle/working/dataset/toy box/248347649_34b1828d79.jpg
#   inflating: /kaggle/working/dataset/toy box/3427962500_ebc77bbde3.jpg
#   inflating: /kaggle/working/dataset/toy box/2544323834_ce8d25262e.jpg
#   inflating: /kaggle/working/dataset/toy box/211042778_343b3b1d4f.jpg
#   inflating: /kaggle/working/dataset/toy box/114877453_c403ed5007.jpg
#   inflating: /kaggle/working/dataset/toy box/3377158766_014cc9f697.jpg
#   inflating: /kaggle/working/dataset/toy box/2847382932_681789221b.jpg
#   inflating: /kaggle/working/dataset/toy box/3086312242_37d0231b2c.jpg
#   inflating: /kaggle/working/dataset/toy box/2694240686_e9e0ee70e6.jpg
#   inflating: /kaggle/working/dataset/toy box/58003820_b54494db73.jpg
#   inflating: /kaggle/working/dataset/toy box/3256564095_f87c734fea.jpg
#   inflating: /kaggle/working/dataset/toy box/266846709_9539b5b5de.jpg
#   inflating: /kaggle/working/dataset/toy box/519944856_5114ed4f7d.jpg
#   inflating: /kaggle/working/dataset/toy box/2145379276_7535173232.jpg
#   inflating: /kaggle/working/dataset/toy box/2530429663_f976a9c994.jpg
#   inflating: /kaggle/working/dataset/toy box/3258332508_6aebdcd525.jpg
#   inflating: /kaggle/working/dataset/shield/2329453344_97ff23f9c0.jpg
#   inflating: /kaggle/working/dataset/shield/2227498733_a179cedeae.jpg
#   inflating: /kaggle/working/dataset/shield/1496313338_328e7c4833.jpg
#   inflating: /kaggle/working/dataset/shield/1737553023_0545002df7.jpg
#   inflating: /kaggle/working/dataset/shield/154968245_0d84eab48e.jpg
#   inflating: /kaggle/working/dataset/shield/2128655660_c9645caaef.jpg
#   inflating: /kaggle/working/dataset/shield/212887827_4982da42a8.jpg
#   inflating: /kaggle/working/dataset/shield/2227320373_59738c02d6.jpg
#   inflating: /kaggle/working/dataset/shield/253484366_f55424a292.jpg
#   inflating: /kaggle/working/dataset/shield/478547126_f805fbe741.jpg
#   inflating: /kaggle/working/dataset/shield/3279335826_ee8788de13.jpg
#   inflating: /kaggle/working/dataset/shield/2737059510_5a48e9265f.jpg
#   inflating: /kaggle/working/dataset/shield/2789669435_9c9a38d488.jpg
#   inflating: /kaggle/working/dataset/shield/72195071_e55efe7b7c.jpg
#   inflating: /kaggle/working/dataset/shield/518512652_8ec45d4f0a.jpg
#   inflating: /kaggle/working/dataset/shield/226910064_477dd11c20.jpg
#   inflating: /kaggle/working/dataset/shield/3318221486_27e9fbd1fc.jpg
#   inflating: /kaggle/working/dataset/shield/72199161_29e0afe0b7.jpg
#   inflating: /kaggle/working/dataset/shield/2042885224_2646d3f09d.jpg
#   inflating: /kaggle/working/dataset/shield/345229467_b2999e39ed.jpg
#   inflating: /kaggle/working/dataset/shield/2407427044_88fb3fc7f4.jpg
#   inflating: /kaggle/working/dataset/shield/260363434_f629961fff.jpg
#   inflating: /kaggle/working/dataset/shield/2790192556_d44998fe89.jpg
#   inflating: /kaggle/working/dataset/shield/2737143786_ee0afcff81.jpg
#   inflating: /kaggle/working/dataset/shield/72209059_2ed44a4d5b.jpg
#   inflating: /kaggle/working/dataset/shield/2789275689_538a4d9aea.jpg
#   inflating: /kaggle/working/dataset/shield/1452061783_9117c46f2d.jpg
#   inflating: /kaggle/working/dataset/shield/163677573_8f7fb8fe89.jpg
#   inflating: /kaggle/working/dataset/shield/365619102_4088b710cc.jpg
#   inflating: /kaggle/working/dataset/shield/2790071080_4e69cf70ac.jpg
#   inflating: /kaggle/working/dataset/shield/3171106186_18745c0acf.jpg
#   inflating: /kaggle/working/dataset/shield/395198646_02063db682.jpg
#   inflating: /kaggle/working/dataset/shield/396911752_b0b71ec9b8.jpg
#   inflating: /kaggle/working/dataset/shield/96626311_f6ffdbe885.jpg
#   inflating: /kaggle/working/dataset/shield/72195328_f43b021480.jpg
#   inflating: /kaggle/working/dataset/shield/2896623937_715d9b5bbc.jpg
#   inflating: /kaggle/working/dataset/shield/72213573_651b275eff.jpg
#   inflating: /kaggle/working/dataset/shield/457714253_44012cfa92.jpg
#   inflating: /kaggle/working/dataset/shield/72202975_146068bf4e.jpg
#   inflating: /kaggle/working/dataset/shield/5944446_1b5472aa92.jpg
#   inflating: /kaggle/working/dataset/shield/1376335416_01e0c3dd0e.jpg
#   inflating: /kaggle/working/dataset/shield/1190047758_97fc7bff65.jpg
#   inflating: /kaggle/working/dataset/shield/2790100408_e63125512d.jpg
#   inflating: /kaggle/working/dataset/shield/1255733366_81da637769.jpg
#   inflating: /kaggle/working/dataset/shield/2789324223_a002965dec.jpg
#   inflating: /kaggle/working/dataset/shield/1454566880_d6843a77c9.jpg
#   inflating: /kaggle/working/dataset/shield/2496768906_83d46ba425.jpg
#   inflating: /kaggle/working/dataset/shield/2303521710_5cba40a0b1.jpg
#   inflating: /kaggle/working/dataset/shield/2956686398_b2f97c0a76.jpg
#   inflating: /kaggle/working/dataset/shield/3458347336_50eb1ce424.jpg
#   inflating: /kaggle/working/dataset/shield/3494869047_955a0daf23.jpg
#   inflating: /kaggle/working/dataset/shield/365616974_693419128d.jpg
#   inflating: /kaggle/working/dataset/shield/348375010_94dcc1226d.jpg
#   inflating: /kaggle/working/dataset/shield/14452814_db62a106e1.jpg
#   inflating: /kaggle/working/dataset/shield/3187791022_aa01238b9d.jpg
#   inflating: /kaggle/working/dataset/shield/3187586494_feffa75018.jpg
#   inflating: /kaggle/working/dataset/shield/2261011446_65b74c1990.jpg
#   inflating: /kaggle/working/dataset/shield/443207623_43d6b3fe59.jpg
#   inflating: /kaggle/working/dataset/shield/756517347_b0e2e3d5a3.jpg
#   inflating: /kaggle/working/dataset/shield/3452944876_5fd17cdd93.jpg
#   inflating: /kaggle/working/dataset/shield/195803850_a6b7704fd0.jpg
#   inflating: /kaggle/working/dataset/shield/566545992_20a7606fda.jpg
#   inflating: /kaggle/working/dataset/shield/109147190_ec2e387635.jpg
#   inflating: /kaggle/working/dataset/shield/2495945377_27d8e94cf9.jpg
#   inflating: /kaggle/working/dataset/shield/3187825492_75b5871bdd.jpg
#   inflating: /kaggle/working/dataset/shield/2177390261_4f51544feb.jpg
#   inflating: /kaggle/working/dataset/shield/365614919_89453d48a8.jpg
#   inflating: /kaggle/working/dataset/shield/1313235086_224f5e5690.jpg
#   inflating: /kaggle/working/dataset/shield/2911245908_5f12ae0760.jpg
#   inflating: /kaggle/working/dataset/shield/467055977_af79d3a5a3.jpg
#   inflating: /kaggle/working/dataset/shield/455770870_966e62823e.jpg
#   inflating: /kaggle/working/dataset/shield/162304260_0fac3b4362.jpg
#   inflating: /kaggle/working/dataset/shield/2083677875_bcafdbc979.jpg
#   inflating: /kaggle/working/dataset/shield/2580637816_580ec499d1.jpg
#   inflating: /kaggle/working/dataset/shield/3224261974_943fa8f649.jpg
#   inflating: /kaggle/working/dataset/shield/2596820397_d2fbf61c18.jpg
#   inflating: /kaggle/working/dataset/shield/207739474_698efbd01d.jpg
#   inflating: /kaggle/working/dataset/shield/478547310_d261cb5be6.jpg
#   inflating: /kaggle/working/dataset/shield/14452818_7c610afd40.jpg
#   inflating: /kaggle/working/dataset/shield/1313343024_4a66a238ea.jpg
#   inflating: /kaggle/working/dataset/shield/365618643_826a03b37c.jpg
#   inflating: /kaggle/working/dataset/shield/354437980_7f9b935ed4.jpg
#   inflating: /kaggle/working/dataset/shield/3475899076_8725c34365.jpg
#   inflating: /kaggle/working/dataset/shield/457714271_fa9db1721a.jpg
#   inflating: /kaggle/working/dataset/shield/3187590512_ded28fa453.jpg
#   inflating: /kaggle/working/dataset/shield/2790239578_3851943210.jpg
#   inflating: /kaggle/working/dataset/shield/2761292850_02972422fb.jpg
#   inflating: /kaggle/working/dataset/shield/2615794531_93c7fc3da4.jpg
#   inflating: /kaggle/working/dataset/shield/3030559170_7c930dfee9.jpg
#   inflating: /kaggle/working/dataset/shield/3176968219_4fcf6c277d.jpg
#   inflating: /kaggle/working/dataset/shield/1175744928_dca973dfaa.jpg
#   inflating: /kaggle/working/dataset/shield/3462653047_d6555e9c20.jpg
#   inflating: /kaggle/working/dataset/shield/479620288_418f6d625b.jpg
#   inflating: /kaggle/working/dataset/shield/365618799_f3ddf177c9.jpg
#   inflating: /kaggle/working/dataset/shield/1968601223_1c456e194d.jpg
#   inflating: /kaggle/working/dataset/shield/2117016544_2f17c0768f.jpg
#   inflating: /kaggle/working/dataset/shield/2686669315_dfe5ac9b1a.jpg
#   inflating: /kaggle/working/dataset/shield/436605826_f4675673ac.jpg
#   inflating: /kaggle/working/dataset/shield/2361093382_8864951c50.jpg
#   inflating: /kaggle/working/dataset/shield/2577355589_c77c15c7df.jpg
#   inflating: /kaggle/working/dataset/shield/467360618_b5334e27a3.jpg
#   inflating: /kaggle/working/dataset/shield/199333652_1f8cb8b99d.jpg
#   inflating: /kaggle/working/dataset/shield/2587177134_66070bd31d.jpg
#   inflating: /kaggle/working/dataset/shield/2337846659_ec9c5991c1.jpg
#   inflating: /kaggle/working/dataset/shield/3176968099_5e9b741d80.jpg
#   inflating: /kaggle/working/dataset/shield/72199312_b18dd869b0.jpg
#   inflating: /kaggle/working/dataset/shield/345320540_5514253988.jpg
#   inflating: /kaggle/working/dataset/shield/495908564_871ddf4fdb.jpg
#   inflating: /kaggle/working/dataset/shield/916348959_ae5a3134ca.jpg
#   inflating: /kaggle/working/dataset/shield/3393417591_e2d2f31f73.jpg
#   inflating: /kaggle/working/dataset/shield/3187757090_5fbbe40aab.jpg
#   inflating: /kaggle/working/dataset/shield/3405272728_e90683529f.jpg
#   inflating: /kaggle/working/dataset/shield/3186957211_454e4478fd.jpg
#   inflating: /kaggle/working/dataset/shield/3477595011_25e338c34e.jpg
#   inflating: /kaggle/working/dataset/shield/3180369450_0a28b9c3c5.jpg
#   inflating: /kaggle/working/dataset/shield/2215441876_2eeaf48120.jpg
#   inflating: /kaggle/working/dataset/shield/458641871_d4679405da.jpg
#   inflating: /kaggle/working/dataset/shield/436583044_cbc819c1bb.jpg
#   inflating: /kaggle/working/dataset/shield/2789358557_ab17f5be7f.jpg
#   inflating: /kaggle/working/dataset/shield/410735420_6b614a16f8.jpg
#   inflating: /kaggle/working/dataset/shield/2789279293_bbd1ef045a.jpg
#   inflating: /kaggle/working/dataset/shield/1811583981_2caf430213.jpg
#   inflating: /kaggle/working/dataset/shield/2789762915_982a919655.jpg
#   inflating: /kaggle/working/dataset/shield/4025359_b3f0605a83.jpg
#   inflating: /kaggle/working/dataset/shield/2789713601_ebf203f55d.jpg
#   inflating: /kaggle/working/dataset/shield/1557519782_19356ff420.jpg
#   inflating: /kaggle/working/dataset/shield/2932927761_67d18382ae.jpg
#   inflating: /kaggle/working/dataset/shield/436594147_87f7cb37d5.jpg
#   inflating: /kaggle/working/dataset/shield/436576227_a7e1c60f23.jpg
#   inflating: /kaggle/working/dataset/shield/3312364283_f46ce3e2be.jpg
#   inflating: /kaggle/working/dataset/shield/2495942529_1a5b774321.jpg
#   inflating: /kaggle/working/dataset/shield/2931701074_5ea722c9a4.jpg
#   inflating: /kaggle/working/dataset/shield/2477362667_009b911477.jpg
#   inflating: /kaggle/working/dataset/shield/253484635_ae54039d0a.jpg
#   inflating: /kaggle/working/dataset/shield/457663492_1834e329b7.jpg
#   inflating: /kaggle/working/dataset/shield/2329422742_3170618d04.jpg
#   inflating: /kaggle/working/dataset/shield/3503359996_76968ae3a2.jpg
#   inflating: /kaggle/working/dataset/shield/2252553130_887358cbbc.jpg
#   inflating: /kaggle/working/dataset/shield/1351457073_516da1d467.jpg
#   inflating: /kaggle/working/dataset/shield/72215649_a5365169c3.jpg
#   inflating: /kaggle/working/dataset/shield/840624260_eebfca0580.jpg
#   inflating: /kaggle/working/dataset/shield/2582847604_9af85c592e.jpg
#   inflating: /kaggle/working/dataset/shield/2966025048_5de71cc032.jpg
#   inflating: /kaggle/working/dataset/shield/436573120_0ba11d53fa.jpg
#   inflating: /kaggle/working/dataset/shield/2933910165_83c4a501bc.jpg
#   inflating: /kaggle/working/dataset/shield/1960081120_db48b9d164.jpg
#   inflating: /kaggle/working/dataset/shield/2556723474_e33ddb7f9c.jpg
#   inflating: /kaggle/working/dataset/shield/72200879_b7a3c2e055.jpg
#   inflating: /kaggle/working/dataset/shield/2310872715_50448375c6.jpg
#   inflating: /kaggle/working/dataset/shield/458624640_8d067daa60.jpg
#   inflating: /kaggle/working/dataset/shield/72209296_61dfb1b8f3.jpg
#   inflating: /kaggle/working/dataset/shield/2687502726_92cd4eca3a.jpg
#   inflating: /kaggle/working/dataset/shield/162377028_f09a4f78ba.jpg
#   inflating: /kaggle/working/dataset/shield/1318766319_ca6af79917.jpg
#   inflating: /kaggle/working/dataset/shield/2790137368_fd837ce58a.jpg
#   inflating: /kaggle/working/dataset/shield/3186747609_8aa2fdc4e7.jpg
#   inflating: /kaggle/working/dataset/shield/452577729_35beef3c56.jpg
#   inflating: /kaggle/working/dataset/shield/723394572_56560faf32.jpg
#   inflating: /kaggle/working/dataset/shield/1718822499_378d02f68c.jpg
#   inflating: /kaggle/working/dataset/shield/73152022_6b63a87019.jpg
#   inflating: /kaggle/working/dataset/shield/2857678664_d06bbc2c29.jpg
#   inflating: /kaggle/working/dataset/shield/2790150874_049bb03d67.jpg
#   inflating: /kaggle/working/dataset/shield/1526896713_ac37a8ea59.jpg
#   inflating: /kaggle/working/dataset/shield/72210181_23d51f5daf.jpg
#   inflating: /kaggle/working/dataset/shield/458626530_7f10100cf9.jpg
#   inflating: /kaggle/working/dataset/shield/3187748526_ed5304d0b6.jpg
#   inflating: /kaggle/working/dataset/shield/3186997835_b656befb41.jpg
#   inflating: /kaggle/working/dataset/shield/207739445_3b6ea04e43.jpg
#   inflating: /kaggle/working/dataset/shield/1719666738_81843e7cc2.jpg
#   inflating: /kaggle/working/dataset/shield/2256406060_26c3779016.jpg
#   inflating: /kaggle/working/dataset/shield/187597738_dd4f01eeaf.jpg
#   inflating: /kaggle/working/dataset/shield/189509556_4c211749f3.jpg
#   inflating: /kaggle/working/dataset/shield/2792534541_36d08cc991.jpg
#   inflating: /kaggle/working/dataset/shield/2601014914_6d2e0bc751.jpg
#   inflating: /kaggle/working/dataset/shield/2790344548_9ef438b60b.jpg
#   inflating: /kaggle/working/dataset/shield/469162337_351e6d24b1.jpg
#   inflating: /kaggle/working/dataset/shield/283731120_cb84cff914.jpg
#   inflating: /kaggle/working/dataset/shield/457714281_86ac984bef.jpg
#   inflating: /kaggle/working/dataset/shield/73156002_d56074e3c8.jpg
#   inflating: /kaggle/working/dataset/shield/14452815_c3cf1822eb.jpg
#   inflating: /kaggle/working/dataset/shield/2737135577_84875e47fe.jpg
#   inflating: /kaggle/working/dataset/shield/3228707371_457de9875a.jpg
#   inflating: /kaggle/working/dataset/shield/3187744806_85bb64b4f6.jpg
#   inflating: /kaggle/working/dataset/shield/3318224760_cdf63e6031.jpg
#   inflating: /kaggle/working/dataset/shield/3187764198_822ae23566.jpg
#   inflating: /kaggle/working/dataset/shield/3393093064_1b47a2b4e2.jpg
#   inflating: /kaggle/working/dataset/shield/3477578831_9694fd203a.jpg
#   inflating: /kaggle/working/dataset/shield/2882967616_da830880a2.jpg
#   inflating: /kaggle/working/dataset/shield/2335466139_ed7524fca2.jpg
#   inflating: /kaggle/working/dataset/shield/3029719595_8cf45fae7b.jpg
#   inflating: /kaggle/working/dataset/shield/2560239646_07bdffe862.jpg
#   inflating: /kaggle/working/dataset/shield/166812886_17b0c82c23.jpg
#   inflating: /kaggle/working/dataset/shield/2789200921_e347a0d25c.jpg
#   inflating: /kaggle/working/dataset/shield/2737724326_89df19e850.jpg
#   inflating: /kaggle/working/dataset/shield/458623464_3fe81bbd24.jpg
#   inflating: /kaggle/working/dataset/shield/478565433_d46e57c098.jpg
#   inflating: /kaggle/working/dataset/shield/283071207_c2d938fe50.jpg
#   inflating: /kaggle/working/dataset/shield/3186713325_ab57f97f53.jpg
#   inflating: /kaggle/working/dataset/shield/2496772128_7360d833b7.jpg
#   inflating: /kaggle/working/dataset/shield/72215082_a5cffea15f.jpg

# %% [markdown]
# Basado en: https://albumentations.ai/docs/examples/tensorflow-example/

# %% [markdown]
# ## Modelo

# %%
# !rm -rf logs

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory



data_dir = "/kaggle/working/dataset"

train_ds, val_ds = image_dataset_from_directory(

    data_dir,

    labels='inferred',

    label_mode='int',

    class_names=None,

    color_mode='rgb',

    batch_size=32,

    image_size=(500, 500),

    shuffle=True,

    seed=37,

    validation_split=0.2,

    subset='both',

    interpolation='bilinear',

)
# Out:
# Found 4000 files belonging to 20 classes.
# Using 3200 files for training.
# Using 800 files for validation.

# %%
HP_NUM_UNITS = hp.HParam('num_units', hp.Discrete([256]))#([64,128,256]))

HP_DROPOUT = hp.HParam('dropout', hp.Discrete([0.0,0.5]))# ([0.0,0.2,0.5]))

HP_LEARNING_RATE = hp.HParam('learning_rate', hp.Discrete([1e-3]))#([1e-3, 1e-4]))

METRIC_ACCURACY = 'accuracy'

with tf.summary.create_file_writer('logs/hparam_tuning').as_default():

    hp.hparams_config(

        hparams=[HP_NUM_UNITS, HP_DROPOUT, HP_LEARNING_RATE],

        metrics=[hp.Metric(METRIC_ACCURACY, display_name='Accuracy')])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

def train_model(hparams,callbacks):

    with mlflow.start_run():

        # Build the base model

        base_model = ResNet50(include_top=False, weights='imagenet', input_shape=(500, 500, 3))

        x = base_model.output

        x = GlobalAveragePooling2D()(x)

        x = Dense(hparams[HP_NUM_UNITS], activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)

        x = Dropout(hparams[HP_DROPOUT])(x)

        output_layer = Dense(20, activation='softmax')(x)



        # Complete model

        model = Model(inputs=base_model.input, outputs=output_layer)



        # Freeze base model layers

        for layer in base_model.layers:

            layer.trainable = False



        # Compile model

        optimizer = Adam(learning_rate=hparams[HP_LEARNING_RATE])

        model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])



        # Define callbacks

        early_stopping = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)

        reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=3, min_lr=1e-6)



        # Use ".keras" file extension for model checkpoint in the new Keras format

        checkpoint_filepath = "best_weights.keras"

        model_checkpoint = ModelCheckpoint(checkpoint_filepath, save_best_only=True, monitor='val_loss', mode='min')



        # Train model

        history = model.fit(

            train_ds,

            validation_data=val_ds,

            epochs=2,

            callbacks= callbacks + [early_stopping, reduce_lr, model_checkpoint]

        )



        # Log hyperparameters and metrics to MLflow

        mlflow.log_param("num_units", hparams[HP_NUM_UNITS])

        mlflow.log_param("dropout", hparams[HP_DROPOUT])

        mlflow.log_param("learning_rate", hparams[HP_LEARNING_RATE])

        mlflow.log_metric("accuracy", max(history.history['accuracy']))



        # Load the best weights and save as final weights in ".h5" format

        model.load_weights(checkpoint_filepath)  # Load the best weights before saving

        final_weights_path = "final_model.weights.h5"

        model.save_weights(final_weights_path)

        mlflow.log_artifact(final_weights_path)



        # Log the model to MLflow

        mlflow.keras.log_model(model, "model")

# %%
session_num = 1

for num_units in HP_NUM_UNITS.domain.values:
    for dropout in HP_DROPOUT.domain.values:
        for learning_rate in HP_LEARNING_RATE.domain.values:
            hparams = {
                HP_NUM_UNITS: num_units,
                HP_DROPOUT: dropout,
                HP_LEARNING_RATE: learning_rate,
            }

            # Specify a unique log directory for each trial
            log_dir = f"logs/hparam_tuning/session_{session_num}"
            tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
            hparams_callback = hp.KerasCallback(log_dir, hparams)

            print(f"--- Starting trial: {session_num}")
            print({h.name: hparams[h] for h in hparams})
            
            # Update train_model function to accept the callbacks dynamically
            train_model(hparams, callbacks=[tensorboard_callback, hparams_callback])
            session_num += 1
# Out:
# --- Starting trial: 1
# {'num_units': 256, 'dropout': 0.0, 'learning_rate': 0.001}
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Epoch 1/2
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730728684.815974      87 service.cc:145] XLA service 0x7dfcfc004b50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1730728684.816045      87 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1730728693.992133      87 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 48s 314ms/step - accuracy: 0.6132 - loss: 4.8197 - val_accuracy: 0.8313 - val_loss: 1.9669 - learning_rate: 0.0010
# Epoch 2/2
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 28s 277ms/step - accuracy: 0.8912 - loss: 1.5508 - val_accuracy: 0.8675 - val_loss: 1.1439 - learning_rate: 0.0010
# 2024/11/04 13:59:19 WARNING mlflow.keras.save: You are saving a Keras model without specifying model signature.
# 2024/11/04 13:59:28 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmpxnjns2d2/model, flavor: keras). Fall back to return ['keras==3.3.3']. Set logging level to DEBUG to see the full traceback.
# 2024/11/04 13:59:28 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# --- Starting trial: 2
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 0.001}
# Epoch 1/2
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 42s 309ms/step - accuracy: 0.4344 - loss: 5.4866 - val_accuracy: 0.8537 - val_loss: 2.2307 - learning_rate: 0.0010
# Epoch 2/2
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 28s 278ms/step - accuracy: 0.8239 - loss: 2.0784 - val_accuracy: 0.8587 - val_loss: 1.4454 - learning_rate: 0.0010
# 2024/11/04 14:00:45 WARNING mlflow.keras.save: You are saving a Keras model without specifying model signature.
# 2024/11/04 14:00:51 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmp68f4l_qj/model, flavor: keras). Fall back to return ['keras==3.3.3']. Set logging level to DEBUG to see the full traceback.
# 2024/11/04 14:00:51 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
